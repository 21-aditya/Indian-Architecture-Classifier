# %%
import math
import numpy as np
from os.path import isfile, join
from keras.layers import Conv2D, MaxPooling2D, Dense, Activation, Dropout, Flatten, Input, AveragePooling2D
from keras.optimizers import adam_v2
from keras.models import Model
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects
from keras.applications.inception_v3 import InceptionV3
from keras.metrics import Precision, Recall

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.1
EPOCHS = 100

# %%
def build_inceptionV3(img_shape=(220, 220, 3), n_classes=9, l2_reg=0.,
                load_pretrained=True, freeze_layers_from='base_model'):
    # Decide if load pretrained weights from imagenet
    if load_pretrained:
        weights = 'imagenet'
    else:
        weights = None

    # Get base model
    base_model = InceptionV3(include_top=False, weights=weights,
                             input_tensor=None, input_shape=img_shape)

    # Add final layers
    x = base_model.output
    x = AveragePooling2D((5, 5), strides=(5, 5), name='avg_pool')(x)
    x = Flatten(name='flatten')(x)
    x = Dense(512, activation='swish', name='dense_1', kernel_initializer='he_uniform')(x)
    x = Dropout(0.1)(x)
    x = Dense(256, activation='swish', name='dense_2', kernel_initializer='he_uniform')(x)
    x = Dropout(0.1)(x)
    predictions = Dense(n_classes, activation='softmax', name='predictions', kernel_initializer='he_uniform')(x)

    # This is the model we will train
    model = Model(inputs=base_model.input, outputs=predictions)

    # Freeze some layers
    if freeze_layers_from is not None:
        if freeze_layers_from == 'base_model':
            print ('   Freezing base model layers')
            for layer in base_model.layers:
                layer.trainable = False
        else:
            for i, layer in enumerate(model.layers):
                print(i, layer.name)
            print ('   Freezing from layer 0 to ' + str(freeze_layers_from))
            for layer in model.layers[:freeze_layers_from]:
               layer.trainable = False
            for layer in model.layers[freeze_layers_from:]:
               layer.trainable = True

    adam = adam_v2.Adam(0.00008) 
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy',Precision(), Recall()])  
    # model.summary()
    return model

# %%
import os
from sklearn.preprocessing import OneHotEncoder
typetoint = {'Cave-Arch':1,'Chola':2,'Hoysala':3,'Kalinga':4,'Kerala':5,'MaruGurjara':6,'Mughal':7,'Rajput':8,'Tibetan':9}
path = "/content/drive/MyDrive/ML-Lab/Data/Replicated+Filtered/LatestFilteredPics"
#loading the saved file once again
features = np.load(os.path.join(path,'features.npy'))
classes = np.load(os.path.join(path,'classnames.npy'))
new_ar = []
class_names = []
for i in range(len(features)):
  features[i] = np.squeeze(features[i], axis=0)
  #features[i] = features[i].reshape(1,220,220,3)
  new_ar.append(features[i].flatten())
  class_names.append(typetoint[classes[i]])
classesint = np.array(class_names)
classlist = []
for i in range(len(classesint)):
  lst = [0,0,0,0,0,0,0,0,0]
  lst[classesint[i]-1] = 1
  classlist.append(lst)
classesint = np.array(classlist)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, classesint, test_size=0.1, random_state=0)
X_train = np.squeeze(X_train, axis=1)
X_test = np.squeeze(X_test, axis=1)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (4988, 220, 220, 3) (4988, 9) (555, 220, 220, 3) (555, 9)

# %%
from PIL import Image
from google.colab.patches import cv2_imshow
cv2_imshow(X_train[1])
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7FB729547390>

# %%
key_list = list(typetoint.keys())
val_list = list(typetoint.values())
key_list[val_list.index(y_train[1].tolist().index(1)+1)]
# Out:
# 'Mughal'

# %%
import tensorflow
csv_logger = tensorflow.keras.callbacks.CSVLogger('/content/drive/MyDrive/ML-Lab/EpochLogs/InceptionV3/Version11.csv')

# %%
model = build_inceptionV3()

history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs= EPOCHS, verbose= 1, validation_split=VALIDATION_SPLIT,
    #steps_per_epoch=X_train.shape[0]//BATCH_SIZE,
    callbacks = [csv_logger]
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# 87924736/87910968 [==============================] - 2s 0us/step
#    Freezing base model layers
# Epoch 1/100
# 141/141 [==============================] - 31s 103ms/step - loss: 10.1595 - accuracy: 0.1642 - precision: 0.1656 - recall: 0.1508 - val_loss: 3.5820 - val_accuracy: 0.2084 - val_precision: 0.2310 - val_recall: 0.1583
# Epoch 2/100
# 141/141 [==============================] - 11s 77ms/step - loss: 3.9043 - accuracy: 0.1920 - precision: 0.2099 - recall: 0.1428 - val_loss: 2.3964 - val_accuracy: 0.2164 - val_precision: 0.3107 - val_recall: 0.0641
# Epoch 3/100
# 141/141 [==============================] - 11s 77ms/step - loss: 2.6477 - accuracy: 0.2110 - precision: 0.2650 - recall: 0.0985 - val_loss: 2.1428 - val_accuracy: 0.2044 - val_precision: 0.4348 - val_recall: 0.0200
# Epoch 4/100
# 141/141 [==============================] - 11s 78ms/step - loss: 2.3163 - accuracy: 0.2036 - precision: 0.3226 - recall: 0.0581 - val_loss: 2.1339 - val_accuracy: 0.1703 - val_precision: 1.0000 - val_recall: 0.0080
# Epoch 5/100
# 141/141 [==============================] - 11s 79ms/step - loss: 2.2128 - accuracy: 0.2107 - precision: 0.3625 - recall: 0.0470 - val_loss: 2.1207 - val_accuracy: 0.1743 - val_precision: 0.4286 - val_recall: 0.0120
# Epoch 6/100
# 141/141 [==============================] - 11s 79ms/step - loss: 2.1395 - accuracy: 0.2199 - precision: 0.3917 - recall: 0.0443 - val_loss: 2.0849 - val_accuracy: 0.1884 - val_precision: 0.5000 - val_recall: 0.0080
# Epoch 7/100
# 141/141 [==============================] - 11s 80ms/step - loss: 2.1081 - accuracy: 0.2341 - precision: 0.4531 - recall: 0.0559 - val_loss: 2.0542 - val_accuracy: 0.2285 - val_precision: 0.6667 - val_recall: 0.0160
# Epoch 8/100
# 141/141 [==============================] - 11s 81ms/step - loss: 2.0644 - accuracy: 0.2517 - precision: 0.4738 - recall: 0.0686 - val_loss: 2.0337 - val_accuracy: 0.2244 - val_precision: 0.4286 - val_recall: 0.0120
# Epoch 9/100
# 141/141 [==============================] - 11s 81ms/step - loss: 2.0060 - accuracy: 0.2713 - precision: 0.4992 - recall: 0.0735 - val_loss: 2.0209 - val_accuracy: 0.2565 - val_precision: 0.7143 - val_recall: 0.0200
# Epoch 10/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.9607 - accuracy: 0.2934 - precision: 0.5676 - recall: 0.0936 - val_loss: 1.9721 - val_accuracy: 0.2806 - val_precision: 0.6111 - val_recall: 0.0441
# Epoch 11/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.9293 - accuracy: 0.3085 - precision: 0.5659 - recall: 0.1051 - val_loss: 1.9332 - val_accuracy: 0.2906 - val_precision: 0.6000 - val_recall: 0.0541
# Epoch 12/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.8836 - accuracy: 0.3186 - precision: 0.5861 - recall: 0.1221 - val_loss: 1.9160 - val_accuracy: 0.3206 - val_precision: 0.5833 - val_recall: 0.0561
# Epoch 13/100
# 141/141 [==============================] - 11s 81ms/step - loss: 1.8402 - accuracy: 0.3477 - precision: 0.5967 - recall: 0.1374 - val_loss: 1.8865 - val_accuracy: 0.3206 - val_precision: 0.4348 - val_recall: 0.0601
# Epoch 14/100
# 141/141 [==============================] - 11s 81ms/step - loss: 1.7782 - accuracy: 0.3651 - precision: 0.6193 - recall: 0.1660 - val_loss: 1.8818 - val_accuracy: 0.3186 - val_precision: 0.5652 - val_recall: 0.0782
# Epoch 15/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.7215 - accuracy: 0.3798 - precision: 0.6516 - recall: 0.1767 - val_loss: 1.8172 - val_accuracy: 0.3467 - val_precision: 0.5842 - val_recall: 0.1182
# Epoch 16/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.6745 - accuracy: 0.4061 - precision: 0.6437 - recall: 0.2016 - val_loss: 1.7865 - val_accuracy: 0.3547 - val_precision: 0.6048 - val_recall: 0.1503
# Epoch 17/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.6421 - accuracy: 0.4192 - precision: 0.6492 - recall: 0.2234 - val_loss: 1.7489 - val_accuracy: 0.3848 - val_precision: 0.6344 - val_recall: 0.1182
# Epoch 18/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.5731 - accuracy: 0.4391 - precision: 0.6754 - recall: 0.2462 - val_loss: 1.8150 - val_accuracy: 0.3627 - val_precision: 0.5546 - val_recall: 0.1323
# Epoch 19/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.5293 - accuracy: 0.4495 - precision: 0.6899 - recall: 0.2606 - val_loss: 1.7664 - val_accuracy: 0.3788 - val_precision: 0.6000 - val_recall: 0.1503
# Epoch 20/100
# 141/141 [==============================] - 11s 82ms/step - loss: 1.4905 - accuracy: 0.4698 - precision: 0.7037 - recall: 0.2778 - val_loss: 1.6696 - val_accuracy: 0.4269 - val_precision: 0.6463 - val_recall: 0.1904
# Epoch 21/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.4637 - accuracy: 0.4825 - precision: 0.7217 - recall: 0.2952 - val_loss: 1.7262 - val_accuracy: 0.4128 - val_precision: 0.6216 - val_recall: 0.1844
# Epoch 22/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.3887 - accuracy: 0.5130 - precision: 0.7385 - recall: 0.3259 - val_loss: 1.6921 - val_accuracy: 0.4188 - val_precision: 0.6136 - val_recall: 0.2164
# Epoch 23/100
# 141/141 [==============================] - 11s 82ms/step - loss: 1.3639 - accuracy: 0.5268 - precision: 0.7397 - recall: 0.3393 - val_loss: 1.6520 - val_accuracy: 0.4008 - val_precision: 0.6524 - val_recall: 0.2144
# Epoch 24/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.2844 - accuracy: 0.5453 - precision: 0.7515 - recall: 0.3665 - val_loss: 1.7020 - val_accuracy: 0.4148 - val_precision: 0.6068 - val_recall: 0.2505
# Epoch 25/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.2535 - accuracy: 0.5640 - precision: 0.7602 - recall: 0.3849 - val_loss: 1.6286 - val_accuracy: 0.4589 - val_precision: 0.6480 - val_recall: 0.2325
# Epoch 26/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.2063 - accuracy: 0.5781 - precision: 0.7774 - recall: 0.4052 - val_loss: 1.6126 - val_accuracy: 0.4589 - val_precision: 0.6406 - val_recall: 0.2786
# Epoch 27/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.1635 - accuracy: 0.5923 - precision: 0.7831 - recall: 0.4326 - val_loss: 1.6199 - val_accuracy: 0.4469 - val_precision: 0.6000 - val_recall: 0.2705
# Epoch 28/100
# 141/141 [==============================] - 12s 82ms/step - loss: 1.1077 - accuracy: 0.6084 - precision: 0.7957 - recall: 0.4598 - val_loss: 1.6323 - val_accuracy: 0.4349 - val_precision: 0.6091 - val_recall: 0.2966
# Epoch 29/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.0771 - accuracy: 0.6251 - precision: 0.7907 - recall: 0.4714 - val_loss: 1.5816 - val_accuracy: 0.4749 - val_precision: 0.6349 - val_recall: 0.3066
# Epoch 30/100
# 141/141 [==============================] - 12s 83ms/step - loss: 1.0125 - accuracy: 0.6592 - precision: 0.8135 - recall: 0.5084 - val_loss: 1.5716 - val_accuracy: 0.4629 - val_precision: 0.6245 - val_recall: 0.3066
# Epoch 31/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.9683 - accuracy: 0.6638 - precision: 0.8103 - recall: 0.5233 - val_loss: 1.5850 - val_accuracy: 0.4669 - val_precision: 0.6309 - val_recall: 0.2946
# Epoch 32/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.9565 - accuracy: 0.6598 - precision: 0.8156 - recall: 0.5300 - val_loss: 1.5266 - val_accuracy: 0.5010 - val_precision: 0.6567 - val_recall: 0.3066
# Epoch 33/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.9128 - accuracy: 0.6843 - precision: 0.8227 - recall: 0.5562 - val_loss: 1.4902 - val_accuracy: 0.5110 - val_precision: 0.6719 - val_recall: 0.3447
# Epoch 34/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.8834 - accuracy: 0.6946 - precision: 0.8189 - recall: 0.5643 - val_loss: 1.5281 - val_accuracy: 0.5090 - val_precision: 0.6932 - val_recall: 0.3487
# Epoch 35/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.8227 - accuracy: 0.7137 - precision: 0.8471 - recall: 0.5961 - val_loss: 1.4983 - val_accuracy: 0.5130 - val_precision: 0.6607 - val_recall: 0.3707
# Epoch 36/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.7698 - accuracy: 0.7385 - precision: 0.8495 - recall: 0.6235 - val_loss: 1.4939 - val_accuracy: 0.5150 - val_precision: 0.6424 - val_recall: 0.3888
# Epoch 37/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.7328 - accuracy: 0.7474 - precision: 0.8577 - recall: 0.6416 - val_loss: 1.5021 - val_accuracy: 0.5351 - val_precision: 0.6314 - val_recall: 0.3948
# Epoch 38/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.6933 - accuracy: 0.7710 - precision: 0.8737 - recall: 0.6658 - val_loss: 1.4723 - val_accuracy: 0.5291 - val_precision: 0.6677 - val_recall: 0.4269
# Epoch 39/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.6861 - accuracy: 0.7654 - precision: 0.8602 - recall: 0.6716 - val_loss: 1.4879 - val_accuracy: 0.5451 - val_precision: 0.6844 - val_recall: 0.4128
# Epoch 40/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.6467 - accuracy: 0.7832 - precision: 0.8768 - recall: 0.6912 - val_loss: 1.4948 - val_accuracy: 0.5571 - val_precision: 0.6646 - val_recall: 0.4289
# Epoch 41/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.5945 - accuracy: 0.7962 - precision: 0.8822 - recall: 0.7160 - val_loss: 1.5140 - val_accuracy: 0.4990 - val_precision: 0.6195 - val_recall: 0.3948
# Epoch 42/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.6222 - accuracy: 0.7815 - precision: 0.8693 - recall: 0.7024 - val_loss: 1.4462 - val_accuracy: 0.5491 - val_precision: 0.6829 - val_recall: 0.4489
# Epoch 43/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.5533 - accuracy: 0.8162 - precision: 0.8908 - recall: 0.7411 - val_loss: 1.4643 - val_accuracy: 0.5531 - val_precision: 0.6494 - val_recall: 0.4529
# Epoch 44/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.5351 - accuracy: 0.8274 - precision: 0.8984 - recall: 0.7565 - val_loss: 1.4154 - val_accuracy: 0.5551 - val_precision: 0.6696 - val_recall: 0.4509
# Epoch 45/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.4978 - accuracy: 0.8367 - precision: 0.8992 - recall: 0.7670 - val_loss: 1.4295 - val_accuracy: 0.5691 - val_precision: 0.6575 - val_recall: 0.4810
# Epoch 46/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.4746 - accuracy: 0.8454 - precision: 0.9067 - recall: 0.7795 - val_loss: 1.3566 - val_accuracy: 0.5932 - val_precision: 0.6730 - val_recall: 0.4990
# Epoch 47/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.4600 - accuracy: 0.8485 - precision: 0.9080 - recall: 0.7850 - val_loss: 1.4447 - val_accuracy: 0.5671 - val_precision: 0.6639 - val_recall: 0.4830
# Epoch 48/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.4541 - accuracy: 0.8501 - precision: 0.9064 - recall: 0.7899 - val_loss: 1.4326 - val_accuracy: 0.5651 - val_precision: 0.6468 - val_recall: 0.4990
# Epoch 49/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.4131 - accuracy: 0.8683 - precision: 0.9220 - recall: 0.8167 - val_loss: 1.4594 - val_accuracy: 0.5671 - val_precision: 0.6548 - val_recall: 0.4790
# Epoch 50/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.3799 - accuracy: 0.8744 - precision: 0.9245 - recall: 0.8207 - val_loss: 1.3814 - val_accuracy: 0.5812 - val_precision: 0.6711 - val_recall: 0.5030
# Epoch 51/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.3897 - accuracy: 0.8777 - precision: 0.9213 - recall: 0.8294 - val_loss: 1.4430 - val_accuracy: 0.5972 - val_precision: 0.6730 - val_recall: 0.4990
# Epoch 52/100
# 141/141 [==============================] - 11s 82ms/step - loss: 0.3727 - accuracy: 0.8822 - precision: 0.9242 - recall: 0.8392 - val_loss: 1.4372 - val_accuracy: 0.5932 - val_precision: 0.6780 - val_recall: 0.5190
# Epoch 53/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.3392 - accuracy: 0.8937 - precision: 0.9338 - recall: 0.8521 - val_loss: 1.4142 - val_accuracy: 0.6032 - val_precision: 0.6917 - val_recall: 0.5170
# Epoch 54/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.3370 - accuracy: 0.8917 - precision: 0.9271 - recall: 0.8528 - val_loss: 1.4784 - val_accuracy: 0.5832 - val_precision: 0.6684 - val_recall: 0.5170
# Epoch 55/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.3160 - accuracy: 0.9009 - precision: 0.9369 - recall: 0.8601 - val_loss: 1.4027 - val_accuracy: 0.6132 - val_precision: 0.6749 - val_recall: 0.5491
# Epoch 56/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2867 - accuracy: 0.9096 - precision: 0.9439 - recall: 0.8741 - val_loss: 1.4001 - val_accuracy: 0.5892 - val_precision: 0.6873 - val_recall: 0.5331
# Epoch 57/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2947 - accuracy: 0.9044 - precision: 0.9423 - recall: 0.8761 - val_loss: 1.4645 - val_accuracy: 0.5872 - val_precision: 0.6625 - val_recall: 0.5311
# Epoch 58/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2839 - accuracy: 0.9096 - precision: 0.9441 - recall: 0.8768 - val_loss: 1.3558 - val_accuracy: 0.6273 - val_precision: 0.7132 - val_recall: 0.5731
# Epoch 59/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2655 - accuracy: 0.9178 - precision: 0.9442 - recall: 0.8855 - val_loss: 1.3167 - val_accuracy: 0.6273 - val_precision: 0.7172 - val_recall: 0.5691
# Epoch 60/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2627 - accuracy: 0.9125 - precision: 0.9403 - recall: 0.8882 - val_loss: 1.3604 - val_accuracy: 0.6333 - val_precision: 0.6861 - val_recall: 0.5651
# Epoch 61/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2673 - accuracy: 0.9185 - precision: 0.9469 - recall: 0.8862 - val_loss: 1.3584 - val_accuracy: 0.6192 - val_precision: 0.7195 - val_recall: 0.5551
# Epoch 62/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2391 - accuracy: 0.9298 - precision: 0.9507 - recall: 0.9022 - val_loss: 1.3606 - val_accuracy: 0.6393 - val_precision: 0.6927 - val_recall: 0.5872
# Epoch 63/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2355 - accuracy: 0.9278 - precision: 0.9498 - recall: 0.9011 - val_loss: 1.4767 - val_accuracy: 0.6232 - val_precision: 0.6706 - val_recall: 0.5671
# Epoch 64/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2432 - accuracy: 0.9234 - precision: 0.9461 - recall: 0.9000 - val_loss: 1.4167 - val_accuracy: 0.6172 - val_precision: 0.6802 - val_recall: 0.5711
# Epoch 65/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2330 - accuracy: 0.9285 - precision: 0.9520 - recall: 0.9055 - val_loss: 1.4274 - val_accuracy: 0.6273 - val_precision: 0.6698 - val_recall: 0.5691
# Epoch 66/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1908 - accuracy: 0.9432 - precision: 0.9619 - recall: 0.9214 - val_loss: 1.3538 - val_accuracy: 0.6253 - val_precision: 0.6956 - val_recall: 0.5952
# Epoch 67/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.2123 - accuracy: 0.9321 - precision: 0.9535 - recall: 0.9136 - val_loss: 1.3457 - val_accuracy: 0.6533 - val_precision: 0.7139 - val_recall: 0.5852
# Epoch 68/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1921 - accuracy: 0.9412 - precision: 0.9594 - recall: 0.9205 - val_loss: 1.4163 - val_accuracy: 0.6353 - val_precision: 0.6939 - val_recall: 0.5952
# Epoch 69/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1839 - accuracy: 0.9445 - precision: 0.9604 - recall: 0.9283 - val_loss: 1.4167 - val_accuracy: 0.6593 - val_precision: 0.7160 - val_recall: 0.6112
# Epoch 70/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.2038 - accuracy: 0.9343 - precision: 0.9548 - recall: 0.9178 - val_loss: 1.4093 - val_accuracy: 0.6232 - val_precision: 0.6806 - val_recall: 0.5892
# Epoch 71/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1777 - accuracy: 0.9465 - precision: 0.9624 - recall: 0.9301 - val_loss: 1.4123 - val_accuracy: 0.6112 - val_precision: 0.6784 - val_recall: 0.5792
# Epoch 72/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1599 - accuracy: 0.9483 - precision: 0.9639 - recall: 0.9343 - val_loss: 1.4298 - val_accuracy: 0.6433 - val_precision: 0.6967 - val_recall: 0.5892
# Epoch 73/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1531 - accuracy: 0.9541 - precision: 0.9691 - recall: 0.9361 - val_loss: 1.4114 - val_accuracy: 0.6473 - val_precision: 0.7053 - val_recall: 0.6092
# Epoch 74/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1586 - accuracy: 0.9543 - precision: 0.9655 - recall: 0.9405 - val_loss: 1.3817 - val_accuracy: 0.6673 - val_precision: 0.7153 - val_recall: 0.6192
# Epoch 75/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1645 - accuracy: 0.9479 - precision: 0.9623 - recall: 0.9332 - val_loss: 1.3865 - val_accuracy: 0.6333 - val_precision: 0.6825 - val_recall: 0.6032
# Epoch 76/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1694 - accuracy: 0.9488 - precision: 0.9637 - recall: 0.9336 - val_loss: 1.3969 - val_accuracy: 0.6493 - val_precision: 0.7067 - val_recall: 0.6132
# Epoch 77/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1644 - accuracy: 0.9474 - precision: 0.9597 - recall: 0.9347 - val_loss: 1.4455 - val_accuracy: 0.6533 - val_precision: 0.7065 - val_recall: 0.6273
# Epoch 78/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1674 - accuracy: 0.9445 - precision: 0.9594 - recall: 0.9312 - val_loss: 1.4681 - val_accuracy: 0.6212 - val_precision: 0.6758 - val_recall: 0.5932
# Epoch 79/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1365 - accuracy: 0.9581 - precision: 0.9719 - recall: 0.9476 - val_loss: 1.4130 - val_accuracy: 0.6553 - val_precision: 0.7063 - val_recall: 0.6313
# Epoch 80/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1417 - accuracy: 0.9570 - precision: 0.9668 - recall: 0.9456 - val_loss: 1.3964 - val_accuracy: 0.6433 - val_precision: 0.6830 - val_recall: 0.6132
# Epoch 81/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1273 - accuracy: 0.9626 - precision: 0.9740 - recall: 0.9521 - val_loss: 1.4463 - val_accuracy: 0.6653 - val_precision: 0.7107 - val_recall: 0.6253
# Epoch 82/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.1354 - accuracy: 0.9588 - precision: 0.9668 - recall: 0.9481 - val_loss: 1.5374 - val_accuracy: 0.6453 - val_precision: 0.6741 - val_recall: 0.6052
# Epoch 83/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1240 - accuracy: 0.9635 - precision: 0.9714 - recall: 0.9526 - val_loss: 1.3746 - val_accuracy: 0.6693 - val_precision: 0.7108 - val_recall: 0.6353
# Epoch 84/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1109 - accuracy: 0.9699 - precision: 0.9787 - recall: 0.9612 - val_loss: 1.4146 - val_accuracy: 0.6693 - val_precision: 0.7095 - val_recall: 0.6413
# Epoch 85/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.1098 - accuracy: 0.9664 - precision: 0.9730 - recall: 0.9570 - val_loss: 1.4542 - val_accuracy: 0.6633 - val_precision: 0.7075 - val_recall: 0.6253
# Epoch 86/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1268 - accuracy: 0.9590 - precision: 0.9682 - recall: 0.9508 - val_loss: 1.4276 - val_accuracy: 0.6493 - val_precision: 0.6911 - val_recall: 0.6232
# Epoch 87/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1215 - accuracy: 0.9635 - precision: 0.9716 - recall: 0.9537 - val_loss: 1.4746 - val_accuracy: 0.6433 - val_precision: 0.6836 - val_recall: 0.6192
# Epoch 88/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.1278 - accuracy: 0.9590 - precision: 0.9667 - recall: 0.9510 - val_loss: 1.4841 - val_accuracy: 0.6373 - val_precision: 0.6763 - val_recall: 0.6112
# Epoch 89/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1569 - accuracy: 0.9514 - precision: 0.9585 - recall: 0.9425 - val_loss: 1.5945 - val_accuracy: 0.6393 - val_precision: 0.6807 - val_recall: 0.6152
# Epoch 90/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1377 - accuracy: 0.9581 - precision: 0.9660 - recall: 0.9485 - val_loss: 1.5075 - val_accuracy: 0.6473 - val_precision: 0.7063 - val_recall: 0.6313
# Epoch 91/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.0929 - accuracy: 0.9766 - precision: 0.9817 - recall: 0.9675 - val_loss: 1.4741 - val_accuracy: 0.6393 - val_precision: 0.6791 - val_recall: 0.6192
# Epoch 92/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1158 - accuracy: 0.9615 - precision: 0.9693 - recall: 0.9561 - val_loss: 1.4597 - val_accuracy: 0.6653 - val_precision: 0.7047 - val_recall: 0.6313
# Epoch 93/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1074 - accuracy: 0.9681 - precision: 0.9745 - recall: 0.9601 - val_loss: 1.5432 - val_accuracy: 0.6613 - val_precision: 0.6941 - val_recall: 0.6413
# Epoch 94/100
# 141/141 [==============================] - 12s 84ms/step - loss: 0.0901 - accuracy: 0.9739 - precision: 0.9795 - recall: 0.9693 - val_loss: 1.4280 - val_accuracy: 0.6573 - val_precision: 0.7011 - val_recall: 0.6253
# Epoch 95/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1188 - accuracy: 0.9652 - precision: 0.9724 - recall: 0.9586 - val_loss: 1.5084 - val_accuracy: 0.6533 - val_precision: 0.6974 - val_recall: 0.6373
# Epoch 96/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.0993 - accuracy: 0.9704 - precision: 0.9748 - recall: 0.9632 - val_loss: 1.4868 - val_accuracy: 0.6593 - val_precision: 0.6938 - val_recall: 0.6313
# Epoch 97/100
# 141/141 [==============================] - 12s 82ms/step - loss: 0.1026 - accuracy: 0.9688 - precision: 0.9754 - recall: 0.9626 - val_loss: 1.3915 - val_accuracy: 0.6733 - val_precision: 0.7089 - val_recall: 0.6393
# Epoch 98/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1131 - accuracy: 0.9621 - precision: 0.9707 - recall: 0.9586 - val_loss: 1.3635 - val_accuracy: 0.6733 - val_precision: 0.7178 - val_recall: 0.6373
# Epoch 99/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.1184 - accuracy: 0.9626 - precision: 0.9691 - recall: 0.9570 - val_loss: 1.5304 - val_accuracy: 0.6653 - val_precision: 0.6961 - val_recall: 0.6473
# Epoch 100/100
# 141/141 [==============================] - 12s 83ms/step - loss: 0.0826 - accuracy: 0.9746 - precision: 0.9791 - recall: 0.9695 - val_loss: 1.4026 - val_accuracy: 0.6854 - val_precision: 0.7045 - val_recall: 0.6593

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 220, 220, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 109, 109, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 109, 109, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 109, 109, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 107, 107, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 107, 107, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 107, 107, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 107, 107, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 107, 107, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 107, 107, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 53, 53, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 53, 53, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 53, 53, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 53, 53, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 51, 51, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 51, 51, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 51, 51, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 12, 12, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 12, 12, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 12, 12, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 12, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 12, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 12, 12, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 12, 12, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 12, 12, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 12, 12, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 12, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 12, 12, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 12, 12, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 12, 12, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 12, 12, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 12, 12, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 12, 12, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 12, 12, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 12, 12, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_59[0][0]']
# ...
#
#  batch_normalization_77 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 5, 5, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 5, 5, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 5, 5, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 5, 5, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 5, 5, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 5, 5, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 5, 5, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 5, 5, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 5, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 2048)   0           ['mixed10[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  dense_1 (Dense)                (None, 512)          1049088     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_2[0][0]']
#
#  predictions (Dense)            (None, 9)            2313        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 22,985,513
# Trainable params: 1,182,729
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
# model.load_weights(savepath1 + 'wts/iv3/inception_v3-06-0.82.hdf5')
# model.load_weights(savepath1 + 'wts/iv3/inception_v3_512-04-0.78.hdf5')
#for 100 epochs
a= model.evaluate(X_test, y_test, verbose=1, batch_size= BATCH_SIZE)
print(a)
# Out:
# 18/18 [==============================] - 2s 128ms/step - loss: 1.4125 - accuracy: 0.6721 - precision: 0.7137 - recall: 0.6468
# [1.4125078916549683, 0.6720720529556274, 0.7137176990509033, 0.6468468308448792]
